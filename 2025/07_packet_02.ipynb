# %% [markdown]
# # 通信を発生させるためのNotebook

# %% [markdown]
# ## 実行例2

# %%
! sudo traceroute -q 1 -T -p 443 8.8.8.8

# %% [markdown]
# ## 実行例3

# %%
! curl https://8.8.8.8

# %% [markdown]
# ## 問題1

# %%
! curl https://8.8.8.8

# %% [markdown]
# ## 問題2

# %%
! ping -c 1 172.18.0.1
