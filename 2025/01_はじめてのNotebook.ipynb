# %% [markdown]
# # はじめてのNotebook

# %% [markdown]
# Notebookは，Webブラウザでpythonなどのプログラムを実行したり，サーバ（linux）自身のコマンドを実行したりできるWebインタフェースです。
#
# このNotebookで入力して実行指示したコマンドやプログラムは、クラウド上にあるサーバ上で実行されています。
#
# 1人に1つサーバを準備しています。

# %% [markdown]
# ## linuxコマンド実行

# %% [markdown]
# linuxのコマンドを実行するには!の後にコマンドを書きます

# %%
! date

# %%
! hostname

# %% [markdown]
# ## pythonを使った簡単な計算

# %% [markdown]
# このnotebookではpythonを実行することができます。pythonを実行するときは!は不要です。
#
# 例えば，単純な四則演算はこんな感じです。

# %%
1 + 3

# %%
10 - 8

# %%
50 / 4

# %%
2 * 3

# %%
100 * ( 4.1 + 3.4 ) - 100

# %% [markdown]
# ### 累乗

# %%
5**2

# %% [markdown]
# ### 剰余

# %%
# 10を3で割った余り
10 % 3

# %% [markdown]
# ### 関数

# %%
# 関数を使うためのおまじない（mathというモジュールを読み込んでいます）
import math

# %%
# 自然対数
math.log(10)

# %%
# コサインの逆関数
math.acos(-1)

# %%
# 指数関数(eのべき乗)
math.exp(1)

# %% [markdown]
# ### 変数を使った計算

# %%
a = 1
b = 2
a + b

# %%
pi = math.acos(-1)

math.tan(pi/4)

# %% [markdown]
# # 適当に何か計算してみましょう
# セルを追加するには+ボタンを押します
